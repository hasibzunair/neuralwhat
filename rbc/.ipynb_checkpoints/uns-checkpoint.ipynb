# %% [markdown]
# # Given an ultrasound image, segment the region of collection of nerves called the Brachial Plexus (BP)

# %% [markdown]
# ref: https://www.kaggle.com/c/ultrasound-nerve-segmentation/data

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import random
import numpy as np
from skimage.io import imsave, imread
from skimage.transform import resize
from skimage.io import imsave
import numpy as np
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Conv2DTranspose
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras import backend as K

data_path = '../input'

# params
image_rows = 420
image_cols = 580


K.set_image_data_format('channels_last')

# %%
print(os.listdir(data_path))
# Out:
# ['train', 'test', 'train_masks.csv', 'sample_submission.csv']

# %%
# helpers
def create_train_data():
    train_data_path = os.path.join(data_path, 'train')
    images = os.listdir(train_data_path)
    total = int(len(images) / 2)

    imgs = np.ndarray((total, image_rows, image_cols), dtype=np.uint8)
    imgs_mask = np.ndarray((total, image_rows, image_cols), dtype=np.uint8)

    i = 0
    print('-'*30)
    print('Creating training images...')
    print('-'*30)
    for image_name in images:
        if 'mask' in image_name:
            continue
        image_mask_name = image_name.split('.')[0] + '_mask.tif'
        img = imread(os.path.join(train_data_path, image_name), as_grey=True)
        img_mask = imread(os.path.join(train_data_path, image_mask_name), as_grey=True)

        img = np.array([img])
        img_mask = np.array([img_mask])

        imgs[i] = img
        imgs_mask[i] = img_mask

        if i % 100 == 0:
            print('Done: {0}/{1} images'.format(i, total))
        i += 1
    print('Loading done.')
    
    return imgs, imgs_mask
    #np.save('imgs_train.npy', imgs)
    #np.save('imgs_mask_train.npy', imgs_mask)
    #print('Saving to .npy files done.')


def load_train_data():
    imgs_train = np.load('imgs_train.npy')
    imgs_mask_train = np.load('imgs_mask_train.npy')
    return imgs_train, imgs_mask_train


def create_test_data():
    train_data_path = os.path.join(data_path, 'test')
    images = os.listdir(train_data_path)
    total = len(images)

    imgs = np.ndarray((total, image_rows, image_cols), dtype=np.uint8)
    imgs_id = np.ndarray((total, ), dtype=np.int32)

    i = 0
    print('-'*30)
    print('Creating test images...')
    print('-'*30)
    for image_name in images:
        img_id = int(image_name.split('.')[0])
        img = imread(os.path.join(train_data_path, image_name), as_grey=True)

        img = np.array([img])

        imgs[i] = img
        imgs_id[i] = img_id

        if i % 100 == 0:
            print('Done: {0}/{1} images'.format(i, total))
        i += 1
    print('Loading done.')
    return imgs, imgs_id
    #np.save('imgs_test.npy', imgs)
    #np.save('imgs_id_test.npy', imgs_id)
    #print('Saving to .npy files done.')


def load_test_data():
    imgs_test = np.load('imgs_test.npy')
    imgs_id = np.load('imgs_id_test.npy')
    return imgs_test, imgs_id

# %%
x_train, y_train = create_train_data()
x_test, y_ids = create_test_data()
# Out:
# ------------------------------
# Creating training images...
# ------------------------------
# Done: 0/5635 images
# Done: 100/5635 images
# Done: 200/5635 images
# Done: 300/5635 images
# Done: 400/5635 images
# Done: 500/5635 images
# Done: 600/5635 images
# /opt/conda/lib/python3.6/site-packages/skimage/external/tifffile/tifffile.py:2611: RuntimeWarning: py_decodelzw encountered unexpected end of stream
#   strip = decompress(strip)
# Done: 700/5635 images
# Done: 800/5635 images
# Done: 900/5635 images
# Done: 1000/5635 images
# Done: 1100/5635 images
# Done: 1200/5635 images
# Done: 1300/5635 images
# Done: 1400/5635 images
# Done: 1500/5635 images
# Done: 1600/5635 images
# Done: 1700/5635 images
# Done: 1800/5635 images
# Done: 1900/5635 images
# Done: 2000/5635 images
# Done: 2100/5635 images
# Done: 2200/5635 images
# Done: 2300/5635 images
# Done: 2400/5635 images
# Done: 2500/5635 images
# Done: 2600/5635 images
# Done: 2700/5635 images
# Done: 2800/5635 images
# Done: 2900/5635 images
# Done: 3000/5635 images
# Done: 3100/5635 images
# Done: 3200/5635 images
# Done: 3300/5635 images
# Done: 3400/5635 images
# Done: 3500/5635 images
# Done: 3600/5635 images
# Done: 3700/5635 images
# Done: 3800/5635 images
# Done: 3900/5635 images
# Done: 4000/5635 images
# Done: 4100/5635 images
# Done: 4200/5635 images
# Done: 4300/5635 images
# Done: 4400/5635 images
# Done: 4500/5635 images
# Done: 4600/5635 images
# Done: 4700/5635 images
# Done: 4800/5635 images
# Done: 4900/5635 images
# Done: 5000/5635 images
# Done: 5100/5635 images
# Done: 5200/5635 images
# Done: 5300/5635 images
# Done: 5400/5635 images
# Done: 5500/5635 images
# Done: 5600/5635 images
# Loading done.
# ------------------------------
# Creating test images...
# ------------------------------
# Done: 0/5508 images
# Done: 100/5508 images
# Done: 200/5508 images
# Done: 300/5508 images
# Done: 400/5508 images
# Done: 500/5508 images
# Done: 600/5508 images
# Done: 700/5508 images
# Done: 800/5508 images
# Done: 900/5508 images
# Done: 1000/5508 images
# Done: 1100/5508 images
# Done: 1200/5508 images
# Done: 1300/5508 images
# Done: 1400/5508 images
# Done: 1500/5508 images
# Done: 1600/5508 images
# Done: 1700/5508 images
# Done: 1800/5508 images
# Done: 1900/5508 images
# Done: 2000/5508 images
# Done: 2100/5508 images
# Done: 2200/5508 images
# Done: 2300/5508 images
# Done: 2400/5508 images
# Done: 2500/5508 images
# Done: 2600/5508 images
# Done: 2700/5508 images
# Done: 2800/5508 images
# Done: 2900/5508 images
# Done: 3000/5508 images
# Done: 3100/5508 images
# Done: 3200/5508 images
# Done: 3300/5508 images
# Done: 3400/5508 images
# Done: 3500/5508 images
# Done: 3600/5508 images
# Done: 3700/5508 images
# Done: 3800/5508 images
# Done: 3900/5508 images
# Done: 4000/5508 images
# Done: 4100/5508 images
# Done: 4200/5508 images
# Done: 4300/5508 images
# Done: 4400/5508 images
# Done: 4500/5508 images
# Done: 4600/5508 images
# Done: 4700/5508 images
# Done: 4800/5508 images
# Done: 4900/5508 images
# Done: 5000/5508 images
# Done: 5100/5508 images
# Done: 5200/5508 images
# Done: 5300/5508 images
# Done: 5400/5508 images
# Done: 5500/5508 images
# Loading done.

# %%
x_train.shape, y_train.shape
# Out:
# ((5635, 420, 580), (5635, 420, 580))

# %%
x_test.shape, y_ids.shape
# Out:
# ((5508, 420, 580), (5508,))

# %% [markdown]
# # Training samples

# %%
idx = random.randint(0, len(x_train))

fig=plt.figure(figsize=(14, 14))
ax1 = fig.add_subplot(1,2,1)
ax1.imshow(np.squeeze(x_train[idx]))
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(np.squeeze(y_train[idx]))

# %% [markdown]
# # Testing samples

# %%
idx = random.randint(0, len(x_test))

plt.imshow(x_test[idx])
plt.title(y_ids[idx])
# Out:
# Text(0.5,1,'1547')

# %% [markdown]
# # Model

# %%
# u-net
def get_unet():
    inputs = Input((img_rows, img_cols, 1))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])

    model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss, metrics=[dice_coef])
    model.summary()
    return model

# %%
img_rows = 96
img_cols = 96
smooth = 1.

def preprocess(imgs):
    imgs_p = np.ndarray((imgs.shape[0], img_rows, img_cols), dtype=np.uint8)
    for i in range(imgs.shape[0]):
        imgs_p[i] = resize(imgs[i], (img_cols, img_rows), preserve_range=True)

    imgs_p = imgs_p[..., np.newaxis]
    return imgs_p


def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %% [markdown]
# # Train

# %%
imgs_train, imgs_mask_train = x_train, y_train

imgs_train = preprocess(imgs_train)
imgs_mask_train = preprocess(imgs_mask_train)

imgs_train = imgs_train.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization

imgs_train -= mean
imgs_train /= std

imgs_mask_train = imgs_mask_train.astype('float32')
imgs_mask_train /= 255.

print("Processing done!")

model = get_unet()
# Out:
# /opt/conda/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Processing done!
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 96, 96, 1)    0
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 96, 96, 32)   320         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 96, 96, 32)   9248        conv2d_39[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 48, 48, 32)   0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 48, 48, 64)   18496       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 48, 48, 64)   36928       conv2d_41[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 24, 24, 64)   0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 24, 24, 128)  73856       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 24, 24, 128)  147584      conv2d_43[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 12, 12, 128)  0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 12, 12, 256)  295168      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 12, 12, 256)  590080      conv2d_45[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 6, 6, 256)    0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 6, 6, 512)    1180160     max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 6, 6, 512)    2359808     conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 12, 12, 256)  524544      conv2d_48[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 12, 12, 512)  0           conv2d_transpose_9[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 12, 12, 256)  1179904     concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 12, 12, 256)  590080      conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 24, 24, 128)  131200      conv2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 24, 24, 256)  0           conv2d_transpose_10[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 24, 24, 128)  295040      concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 24, 24, 128)  147584      conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 48, 48, 64)   32832       conv2d_52[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 48, 48, 128)  0           conv2d_transpose_11[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 48, 48, 64)   73792       concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 48, 48, 64)   36928       conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 96, 96, 32)   8224        conv2d_54[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 96, 96, 64)   0           conv2d_transpose_12[0][0]
#                                                                  conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 96, 96, 32)   18464       concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 96, 96, 32)   9248        conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 96, 96, 1)    33          conv2d_56[0][0]
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Run training loop

# %%
imgs_train.shape, imgs_mask_train.shape
# Out:
# ((5635, 96, 96, 1), (5635, 96, 96, 1))

# %%
K.set_image_data_format('channels_last')

model_checkpoint = ModelCheckpoint('uns.h5', monitor='val_loss', save_best_only=True)
model.fit(imgs_train, imgs_mask_train, batch_size=32, nb_epoch=20, verbose=1, shuffle=True,
          validation_split=0.2,
          callbacks=[model_checkpoint])
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:6: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 4508 samples, validate on 1127 samples
# Epoch 1/20
# 4508/4508 [==============================] - 33s 7ms/step - loss: -0.0237 - dice_coef: 0.0237 - val_loss: -0.0244 - val_dice_coef: 0.0244
# Epoch 2/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.0263 - dice_coef: 0.0263 - val_loss: -0.0363 - val_dice_coef: 0.0363
# Epoch 3/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.2264 - dice_coef: 0.2264 - val_loss: -0.3338 - val_dice_coef: 0.3338
# Epoch 4/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.3599 - dice_coef: 0.3599 - val_loss: -0.3948 - val_dice_coef: 0.3948
# Epoch 5/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.3897 - dice_coef: 0.3897 - val_loss: -0.4179 - val_dice_coef: 0.4179
# Epoch 6/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.4148 - dice_coef: 0.4148 - val_loss: -0.4275 - val_dice_coef: 0.4275
# Epoch 7/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.4332 - dice_coef: 0.4332 - val_loss: -0.4480 - val_dice_coef: 0.4480
# Epoch 8/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.4466 - dice_coef: 0.4466 - val_loss: -0.4605 - val_dice_coef: 0.4605
# Epoch 9/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.4621 - dice_coef: 0.4621 - val_loss: -0.4489 - val_dice_coef: 0.4489
# Epoch 10/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.4742 - dice_coef: 0.4742 - val_loss: -0.4945 - val_dice_coef: 0.4945
# Epoch 11/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.4917 - dice_coef: 0.4917 - val_loss: -0.5087 - val_dice_coef: 0.5087
# Epoch 12/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.4986 - dice_coef: 0.4986 - val_loss: -0.4981 - val_dice_coef: 0.4981
# Epoch 13/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.5029 - dice_coef: 0.5029 - val_loss: -0.5282 - val_dice_coef: 0.5282
# Epoch 14/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.5258 - dice_coef: 0.5258 - val_loss: -0.5443 - val_dice_coef: 0.5443
# Epoch 15/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.5330 - dice_coef: 0.5330 - val_loss: -0.5503 - val_dice_coef: 0.5503
# Epoch 16/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.5331 - dice_coef: 0.5331 - val_loss: -0.5128 - val_dice_coef: 0.5128
# Epoch 17/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.5431 - dice_coef: 0.5431 - val_loss: -0.5622 - val_dice_coef: 0.5622
# Epoch 18/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.5494 - dice_coef: 0.5494 - val_loss: -0.5607 - val_dice_coef: 0.5607
# Epoch 19/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.5628 - dice_coef: 0.5628 - val_loss: -0.5699 - val_dice_coef: 0.5699
# Epoch 20/20
# 4508/4508 [==============================] - 31s 7ms/step - loss: -0.5715 - dice_coef: 0.5715 - val_loss: -0.5725 - val_dice_coef: 0.5725

# %% [markdown]
# # Test!

# %%
imgs_test, imgs_id_test = x_test, y_ids
imgs_test = preprocess(imgs_test)

imgs_test = imgs_test.astype('float32')
imgs_test -= mean
imgs_test /= std

print("Loading uns")
model.load_weights('uns.h5')

imgs_mask_test = model.predict(imgs_test, verbose=1)
np.save('imgs_mask_test.npy', imgs_mask_test)
print("Saved!")
# Out:
# /opt/conda/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Loading uns
# 5508/5508 [==============================] - 12s 2ms/step
# Saved!

# %%
idx = random.randint(0, len(imgs_mask_test))
i = imgs_mask_test[idx]
i = i[:, :, 0]
i.shape
# Out:
# (96, 96)

# %%
plt.imshow(i)

# %% [markdown]
# The end...for now
